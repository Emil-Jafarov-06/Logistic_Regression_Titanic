# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from warnings import filterwarnings
filterwarnings('ignore')
from sklearn import metrics as sm
from sklearn import preprocessing as sp

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df = df.drop(columns = ['Cabin']).dropna()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop(columns = ['Survived']), df['Survived'], test_size=0.2,random_state=42)

# %%
X_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 708          709       1                               Cleaver, Miss. Alice
# 240          241       3                              Zabour, Miss. Thamine
# 382          383       3                                 Tikkanen, Mr. Juho
# 792          793       3                            Sage, Miss. Stella Anna
# 683          684       3                        Goodwin, Mr. Charles Edward
# ..           ...     ...                                                ...
# 107          108       3                             Moss, Mr. Albert Johan
# 271          272       3                       Tornquist, Mr. William Henry
# 862          863       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 436          437       3               Ford, Miss. Doolina Margaret "Daisy"
# 103          104       3                         Johansson, Mr. Gustaf Joel
#
# ...

# %%
#X_train['Ticket_Cat'] = X_train['Ticket'].apply(lambda x : 0 if x.isnumeric() else 1)

# %%
#X_test['Ticket_Cat'] = X_test['Ticket'].apply(lambda x : 0 if x.isnumeric() else 1)

# %%
X_train.drop(columns = ['PassengerId', 'Name', 'Ticket'], inplace=True)

# %%
X_test.drop(columns = ['PassengerId', 'Name', 'Ticket'], inplace=True)

# %%
X_train = X_train.merge(pd.get_dummies(X_train[['Sex', 'Embarked']], drop_first=True, dtype=int), left_index=True, right_index=True).drop(columns = ['Sex', 'Embarked'])

# %%
X_test = X_test.merge(pd.get_dummies(X_test[['Sex', 'Embarked']], drop_first=True, dtype=int), left_index=True, right_index=True).drop(columns = ['Sex', 'Embarked'])

# %%
X_train.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare    Sex_male  \
# count  711.000000  711.000000  711.000000  711.000000  711.000000  711.000000
# mean     2.322082   29.511730    0.554149    0.382560   32.060354    0.663854
# std      0.835180   13.144679    1.168643    0.804865   49.195227    0.472722
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.895800    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.500000    1.000000
# 75%      3.000000   36.000000    1.000000    0.000000   30.695800    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#        Embarked_Q  Embarked_S
# count  711.000000  711.000000
# mean     0.091421    0.722925
# std      0.288409    0.447869
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      0.000000    1.000000
# ...

# %%
X_train['Age'].value_counts()
# Out:
# Age
# 28.00    164
# 24.00     24
# 22.00     22
# 21.00     21
# 19.00     21
#         ...
# 74.00      1
# 70.00      1
# 0.67       1
# 23.50      1
# 57.00      1
# Name: count, Length: 85, dtype: int64

# %%
X_train['Age'].astype(int)
# Out:
# 708    22
# 240    28
# 382    32
# 792    28
# 683    14
#        ..
# 107    28
# 271    25
# 862    48
# 436    21
# 103    33
# Name: Age, Length: 711, dtype: int64

# %%
X_train[X_train['Age'] < 10]
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  Embarked_S
# 119       3  2.00      4      2   31.2750         0           0           1
# 261       3  3.00      4      2   31.3875         1           0           1
# 7         3  2.00      3      1   21.0750         1           0           1
# 813       3  6.00      4      2   31.2750         0           0           1
# 182       3  9.00      4      2   31.3875         1           0           1
# 469       3  0.75      2      1   19.2583         0           0           0
# 165       3  9.00      0      2   20.5250         1           0           1
# 381       3  1.00      0      2   15.7417         0           0           0
# 445       1  4.00      0      2   81.8583         1           0           1
# 24        3  8.00      3      1   21.0750         0           0           1
# 183       2  1.00      2      1   39.0000         1           0           1
# ...

# %%
Y_train.loc[X_train[(X_train['Age'] < 35) & (X_train['Age'] > 25)].index].sum()
# Out:
# np.int64(95)

# %%
def categorize(x):
    if(x < 5):
        return 1
    if(x < 15):
        return 2
    if(x < 20):
        return 3
    if(x < 25):
        return 4
    if(x < 30):
        return 5
    if(x < 35):
        return 6
    if(x < 40):
        return 7
    if(x < 50):
        return 8
    if(x < 60):
        return 9
    if(x >= 60):
        return 10

# %%
#X_train['Age']=X_train['Age'].apply(categorize)

# %%
#X_test['Age'] = X_test['Age'].apply(categorize)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  Embarked_S
# 708       1  22.0      0      0  151.5500         0           0           1
# 240       3  28.0      1      0   14.4542         0           0           0
# 382       3  32.0      0      0    7.9250         1           0           1
# 792       3  28.0      8      2   69.5500         0           0           1
# 683       3  14.0      5      2   46.9000         1           0           1
# ..      ...   ...    ...    ...       ...       ...         ...         ...
# 107       3  28.0      0      0    7.7750         1           0           1
# 271       3  25.0      0      0    0.0000         1           0           1
# 862       1  48.0      0      0   25.9292         0           0           1
# 436       3  21.0      2      2   34.3750         0           0           1
# 103       3  33.0      0      0    8.6542         1           0           1
#
# [711 rows x 8 columns]

# %%
X_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  Embarked_S
# 281       3  28.0      0      0    7.8542         1           0           1
# 435       1  14.0      1      2  120.0000         0           0           1
# 39        3  14.0      1      0   11.2417         0           0           0
# 418       2  30.0      0      0   13.0000         1           0           1
# 585       1  18.0      0      2   79.6500         0           0           1
# ..      ...   ...    ...    ...       ...       ...         ...         ...
# 433       3  17.0      0      0    7.1250         1           0           1
# 807       3  18.0      0      0    7.7750         0           0           1
# 25        3  38.0      1      5   31.3875         0           0           1
# 85        3  33.0      3      0   15.8500         0           0           1
# 10        3   4.0      1      1   16.7000         0           0           1
#
# [178 rows x 8 columns]

# %%
lr = LogisticRegression(C=100000000)

# %%
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=100000000)

# %%
lr.score(X_train, Y_train)
# Out:
# 0.8002812939521801

# %%
lr.score(X_test, Y_test)
# Out:
# 0.7808988764044944

# %%
sm.balanced_accuracy_score(Y_train,lr.predict(X_train))
# Out:
# 0.7826526333445152
